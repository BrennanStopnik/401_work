# %%
import pandas
from sqlalchemy import create_engine

# %%
#1) import CSV -> pandas DF -> Sqlite via Alchemy

# Create the engine to connect to a sqllite database
engine = create_engine("sqlite+pysqlite:///:memory:")

# Read data from CSV, loaded as a dataframe object
data = pandas.read_csv('tips.csv')

# Write data into the table in sqllite database
data.to_sql('tips', engine)
# Out:
# 244

# %%
data
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
from sqlalchemy import text
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM tips"))
    for row in result:
      print(row)
# Out:
# (0, 16.99, 1.01, 'No', 'Sun', 'Dinner', 2)
# (1, 10.34, 1.66, 'No', 'Sun', 'Dinner', 3)
# (2, 21.01, 3.5, 'No', 'Sun', 'Dinner', 3)
# (3, 23.68, 3.31, 'No', 'Sun', 'Dinner', 2)
# (4, 24.59, 3.61, 'No', 'Sun', 'Dinner', 4)
# (5, 25.29, 4.71, 'No', 'Sun', 'Dinner', 4)
# (6, 8.77, 2.0, 'No', 'Sun', 'Dinner', 2)
# (7, 26.88, 3.12, 'No', 'Sun', 'Dinner', 4)
# (8, 15.04, 1.96, 'No', 'Sun', 'Dinner', 2)
# (9, 14.78, 3.23, 'No', 'Sun', 'Dinner', 2)
# (10, 10.27, 1.71, 'No', 'Sun', 'Dinner', 2)
# (11, 35.26, 5.0, 'No', 'Sun', 'Dinner', 4)
# (12, 15.42, 1.57, 'No', 'Sun', 'Dinner', 2)
# (13, 18.43, 3.0, 'No', 'Sun', 'Dinner', 4)
# (14, 14.83, 3.02, 'No', 'Sun', 'Dinner', 2)
# (15, 21.58, 3.92, 'No', 'Sun', 'Dinner', 2)
# (16, 10.33, 1.67, 'No', 'Sun', 'Dinner', 3)
# (17, 16.29, 3.71, 'No', 'Sun', 'Dinner', 3)
# (18, 16.97, 3.5, 'No', 'Sun', 'Dinner', 3)
# (19, 20.65, 3.35, 'No', 'Sat', 'Dinner', 3)
# (20, 17.92, 4.08, 'No', 'Sat', 'Dinner', 2)
# (21, 20.29, 2.75, 'No', 'Sat', 'Dinner', 2)
# ...

# %%
#2) SQL database -> table -> Pandas DF via Alchemy
import pandas as pd
from sqlalchemy import create_engine

# SQLAlchemy connectable
cnx = engine.connect()

# table named 'tips' will be returned as a dataframe.
df = pd.read_sql_table('tips', cnx)
df
# Out:
#      index  total_bill   tip smoker   day    time  size
# 0        0       16.99  1.01     No   Sun  Dinner     2
# 1        1       10.34  1.66     No   Sun  Dinner     3
# 2        2       21.01  3.50     No   Sun  Dinner     3
# 3        3       23.68  3.31     No   Sun  Dinner     2
# 4        4       24.59  3.61     No   Sun  Dinner     4
# ..     ...         ...   ...    ...   ...     ...   ...
# 239    239       29.03  5.92     No   Sat  Dinner     3
# 240    240       27.18  2.00    Yes   Sat  Dinner     2
# 241    241       22.67  2.00    Yes   Sat  Dinner     2
# 242    242       17.82  1.75     No   Sat  Dinner     2
# 243    243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# !pip3 install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 44 kB 2.0 MB/s eta 0:00:011
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# IMPORT THE SQALCHEMY LIBRARY's CREATE_ENGINE METHOD
from sqlalchemy import create_engine

# DEFINE THE DATABASE CREDENTIALS
user = 'root'
password = '***'
host = '127.0.0.1'
port = 3306
database = 'test'

# PYTHON FUNCTION TO CONNECT TO THE MYSQL DATABASE AND
# RETURN THE SQLACHEMY ENGINE OBJECT
def get_connection():
	return create_engine(
		url="mysql+pymysql://{0}:{1}@{2}:{3}/{4}".format(
			user, password, host, port, database
		)
	)

if __name__ == '__main__':

	try:

		# GET THE CONNECTION OBJECT (ENGINE) FOR THE DATABASE
		engine = get_connection()
		print(
			f"Connection to the {host} for user {user} created successfully.")
	except Exception as ex:
		print("Connection could not be made due to the following error: \n", ex)
# Out:
# Connection to the 127.0.0.1 for user root created successfully.

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 9.3 MB 2.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 486 kB 14.0 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import mysql.connector

cnx = mysql.connector.connect(user='root', password='***',
                              host='127.0.0.1',
                              database='test')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/mysql/connector/connection_cext.py:302, in CMySQLConnection._open_connection(self)
#     301 try:
# --> 302     self._cmysql.connect(**cnx_kwargs)
#     303     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: YES)
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[9], line 3
#       1 import mysql.connector
# ----> 3 cnx = mysql.connector.connect(user='root', password='***',
#       4                               host='127.0.0.1',
#       5                               database='test')
#
# ...

# %%
# !mysqld --help --verbose
# Out:
# /bin/bash: mysqld: command not found
